# %%
import pandas as pd

# %%
df = pd.read_csv("docker_stats.csv")
df['Timestamp'] = pd.to_datetime(df['Timestamp'],unit='s')

# %%
df
# Out:
# Empty DataFrame
# Columns: [Timestamp, Container, Name, ID, CPUPerc, MemUsage, MemPerc, NetIO, BlockIO, PIDs]
# Index: []
